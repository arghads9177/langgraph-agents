# %% [markdown]
# # Travel Planner
#
# A simple implementation with routing

# %%
import os
from dotenv import load_dotenv
from typing import Any, Dict, List, Optional, Literal, Set, TypedDict
from pydantic import BaseModel, Field, ValidationError
from IPython.display import display, Image, Markdown
import json
import datetime
# LangGraph StateGraph import (assume installed)
from langgraph.graph import StateGraph, START, END
from langgraph.types import Command

# LangChain imports (LLM & Chains)
from langchain_openai import ChatOpenAI
from langchain import LLMChain, PromptTemplate
from langchain.output_parsers import PydanticOutputParser

# Tavily search
from langchain_tavily import TavilySearch

# %%
load_dotenv()
# Out:
# True

# %%
# Setup LLM clients using env keys
OPENAI_API_KEY = os.getenv("OPENAI_API_KEY")
if not OPENAI_API_KEY:
    raise RuntimeError("OPENAI_API_KEY not set in environment. Set it in .env or env vars before running.")

llm = ChatOpenAI(model="gpt-4", temperature=0.0)

# %%
# Setup Tavily client (assume TAVILY_API_KEY present)
TAVILY_API_KEY = os.getenv("TAVILY_API_KEY")
if not TAVILY_API_KEY:
    raise RuntimeError("TAVILY_API_KEY not set in environment. Set it in .env or env vars before running.")

# instantiate tool
tavily_tool = TavilySearch(max_results = 5)

# %%
class Constraints(BaseModel):
    origin: Optional[str] = None
    city: Optional[str] = None
    date: Optional[str] = None
    return_date: Optional[str] = None
    days: Optional[int] = None
    budget_per_person: Optional[float] = None
    interests: Optional[str] = None
    transport_constraints: Optional[Dict[str, Any]] = None
    hotel_constraints: Optional[Dict[str, Any]] = None

class TransportOption(BaseModel):
    mode: str
    depart: str
    arrive: str
    duration_min: Optional[str]
    price_per_person: Optional[str]
    notes: Optional[str] = None

class HotelOption(BaseModel):
    name: str
    rating: Optional[float]
    price_per_night: float
    distance_from_center_km: Optional[float]
    amenities: List[str] = Field(default_factory=list)
    notes: Optional[str] = None

class ItineraryItem(BaseModel):
    day: int
    morning: str
    afternoon: str
    evening: str
    notes: Optional[str] = None

class Intention(BaseModel):
    type: Literal["travel_plan","hotel_only","transport_only","unrelated"]

class PlannerState(TypedDict):
    goal: str
    intent: Optional[str]
    constraints: Optional[Constraints] = None
    transport_options: List[TransportOption] = Field(default_factory=list)
    hotel_options: List[HotelOption] = Field(default_factory=list)
    itinerary: List[ItineraryItem] = Field(default_factory=list)
    # subtasks: List[Subtask] = Field(default_factory=list)
    # policy: Dict[str, Any] = Field(default_factory=lambda: {"max_retries": 2, "worker_timeout": 12.0})
    final_plan: Optional[str] = None

# %%
# Supervisor LLM with intentation output
supervisor_llm = llm.with_structured_output(Intention, method="function_calling")

# %%
# Supervisor prompt to classify user intent
supervisor_prompt = PromptTemplate(
    input_variables=["goal"],
    template=(
        "You are an expert supervisor of a Travel Planner.\n"
        "Classify the user's travel planning intent based on the goal below.\n"
        "Possible intents are:\n"
        "1. travel_plan - planning a full trip\n"
        "2. hotel_only - only looking for hotel options\n"
        "3. transport_only - only looking for transport options\n"
        "4. unrelated - not related to travel planning or transport booking or hotel booking\n\n"
        "Goal: {goal}\n\n"
        "Respond with ONLY the intent type as one of these exact values: travel_plan, hotel_only, transport_only, unrelated.\n"
        "Do NOT include any explanation, markdown, or extra text. Output only the value."
    )
)

# Supervisor chain
supervisor_chain = supervisor_prompt | supervisor_llm

# Planner promt and chain
constraints_parser = PydanticOutputParser(pydantic_object=Constraints)
format_instructions = constraints_parser.get_format_instructions()

planner_prompt_template = f"""
You are an assistant that extracts travel constraints from a user query.
Return ONLY valid JSON matching the Constraints model below as a single JSON object.
Include all keys in the output, even if the value is null.
If the user query contains any specific requirements for transport (such as preferred mode, timing, class, etc.), include them as key-value pairs inside the "transport_constraints" object. If there are specific hotel requirements (such as star rating, amenities, location, etc.), include them as key-value pairs inside the "hotel_constraints" object. If there are no such requirements, set these fields to null.
Do NOT include any explanation, markdown, or code block formatting (no triple backticks).
Do NOT include trailing commas in the JSON.

Constraints model:
  "origin": string or null,
  "city": string or null,
  "date": string (YYYY-MM-DD) or null,
  "return_date": string (YYYY-MM-DD) or null,
  "days": integer or null,
  "budget_per_person": float or null,
  "interests": string or null,
  "transport_constraints": object or null,
  "hotel_constraints": object or null

User query:
{{text}}

Respond ONLY with valid JSON matching the model above.
"""

planner_prompt = PromptTemplate(
    input_variables=["text"],
    template=planner_prompt_template
)
planner_chain = planner_prompt | llm

# %%
# Define supervisor node function
def supervisor_node(state: PlannerState) -> PlannerState:
    goal = state.get("goal")
    if not goal:
        raise ValueError("Goal is required in the state.")

    result = supervisor_chain.invoke({"goal": goal})
    print(f"Supervisor raw output: {result.type}")
    try:
        
        return {
            "goal": goal,
            "intent": result.type,
            "final_plan": None
        }
    except ValidationError as e:
        print(f"Validation error parsing intention: {e}")
        return {
            "goal": goal,
            "intent": "unrelated",
            "final_plan": None
        }

# %%
# Define supervisor gate
def supervisor_gate(state: PlannerState) -> Literal["plan", "unrelated"]:
    if state.get("intent") in ["travel_plan", "hotel_only", "transport_only"]:
        return "plan"
    return "unrelated"

# %%
def planner_node(state: PlannerState):
    goal = state.get("goal")
    if not goal:
        raise ValueError("Goal is required in the state.")

    try:
        constraints = planner_chain.invoke({"text": goal})
        print(constraints.content)
        constraints_model = constraints_parser.parse(constraints.content)
    except Exception as e:
        print("Extractor parse error:", e)
        constraints_model = Constraints()

    # Transport intent: require origin and city
    if state.get("intent") == "transport_only":
        missing = []
        if not constraints_model.origin:
            missing.append("origin")
        if not constraints_model.city:
            missing.append("destination city")
        if missing:
            message = f"To find transport options, please provide the following missing information: {', '.join(missing)}."
            return Command(goto=END, update={"final_plan": {"message": message}})
        return Command(goto="transport", update={"constraints": constraints_model})

    # Hotel intent: require city
    elif state.get("intent") == "hotel_only":
        if not constraints_model.city:
            message = "To find hotel options, please provide the destination city."
            return Command(goto=END, update={"final_plan": {"message": message}})
        return Command(goto="hotel", update={"constraints": constraints_model})

    else:
        missing = []
        if not constraints_model.origin:
            missing.append("origin")
        if not constraints_model.city:
            missing.append("destination city")
        if missing:
            message = f"To find transport options, please provide the following missing information: {', '.join(missing)}."
            return Command(goto=END, update={"final_plan": {"message": message}})
        if not constraints_model.city:
            message = "To find hotel options, please provide the destination city."
            return Command(goto=END, update={"final_plan": {"message": message}})
        return Command(goto=["transport", "hotel", "itinerary"], update={"constraints": constraints_model})

# %%
# Define end unrelated node
def end_unrelated_node(state: PlannerState) -> PlannerState:
    return {
        "goal": state["goal"],
        "intent": state["intent"],
        "final_plan": {"message": "The request was unrelated to travel planning."}
    }

# %%
# Define the prompt templates and chains for transport agent, hotel_agent, and itinerary_agent

transport_prompt_template = (
    "You are an expert travel assistant. Extract and return a JSON array of TransportOption objects (at least one) "
    "from the following transport search results. Respond ONLY with valid JSON matching the model below. "
    "Do not include any explanation, markdown, or extra text.\n\n"
    "Raw transport search results:\n"
    "{search_results}\n\n"
    "TransportOption model:\n"
    "  \"mode\": string,\n"
    "  \"depart\": string,\n"
    "  \"arrive\": string,\n"
    "  \"duration_min\": string or null,\n"
    "  \"price_per_person\": string or null,\n"
    "  \"notes\": string or null"
)
transport_prompt = PromptTemplate(
    input_variables=["search_results"],
    template=transport_prompt_template
)
transport_chain = transport_prompt | llm

hotel_prompt_template = (
    "You are an expert travel assistant. Extract and return a JSON array of HotelOption objects (at least one) "
    "from the following hotel search results. Respond ONLY with valid JSON matching the model below. "
    "Do not include any explanation, markdown, or extra text.\n\n"
    "Raw hotel search results:\n"
    "{search_results}\n\n"
    "HotelOption model:\n"
    "  \"name\": string,\n"
    "  \"rating\": float or null,\n"
    "  \"price_per_night\": float or 0,\n"
    "  \"distance_from_center_km\": float or null,\n"
    "  \"amenities\": array of strings,\n"
    "  \"notes\": string or null"
)
hotel_prompt = PromptTemplate(
    input_variables=["search_results"],
    template=hotel_prompt_template
)
hotel_chain = hotel_prompt | llm

itinerary_prompt_template = (
    "You are an expert travel assistant that creates a day-wise itinerary based on the following search results and user constraints. "
    "Your response must be a JSON array of ItineraryItem objects. "
    "Do not include any explanation, markdown, or extra text.\n\n"
    "Raw itinerary search results:\n"
    "{search_results}\n\n"
    "User constraints:\n"
    "{constraints}\n\n"
    "ItineraryItem model:\n"
    "  \"day\": integer,\n"
    "  \"morning\": string,\n"
    "  \"afternoon\": string,\n"
    "  \"evening\": string,\n"
    "  \"notes\": string or null (optional)\n"
    "Create a detailed day-wise itinerary that matches the constraints."
)
itinerary_prompt = PromptTemplate(
    input_variables=["search_results", "constraints"],
    template=itinerary_prompt_template
)
itinerary_chain = itinerary_prompt | llm

# %%
#  Define the transport node
def transport_node(state: PlannerState) -> PlannerState:
    print("In transport node")
    constraints = state.get("constraints")
    if not constraints:
        raise ValueError("Constraints are required in the state for transport planning.")

    constraints_dict = constraints.model_dump() if hasattr(constraints, "dict") else constraints
    origin = constraints_dict.get("origin") or "any city in India"
    city = constraints_dict.get("city") or "any city in India"
    date = constraints_dict.get("date") or datetime.date.today().isoformat()
    days = constraints_dict.get("days") or 1
    budget = constraints_dict.get("budget_per_person") or "any"
    interests = constraints_dict.get("interests") or "none"
    query = (
        f"Transport options from {origin} to {city} on {date} for {days} day(s), "
        f"budget {budget}, interests: {interests}. "
        "Return provider, mode, depart, arrive, duration in minutes, price per person, and notes."
    )
    print("Transport search query:", query)

    search_result = tavily_tool.invoke({"query": query})
    print("Raw transport search result:", search_result)

    llm_input = {"search_results": search_result}

    try:
        transport_options = transport_chain.invoke(llm_input)
        print("LLM transport options raw output:", transport_options)
        transport_options = getattr(transport_options, "content", transport_options)
        print("LLM transport options content:", transport_options)
        transport_options_list = json.loads(transport_options)
        transport_options = [TransportOption(**item) for item in transport_options_list]
    except Exception as e:
        print("Transport parse error:", e)
        transport_options = []

    return {
        "transport_options": transport_options
    }

# %%
# Define the hotel node
def hotel_node(state: PlannerState) -> PlannerState:
    print("In hotel node")
    constraints = state.get("constraints")
    if not constraints:
        raise ValueError("Constraints are required in the state for hotel planning.")

    constraints_dict = constraints.model_dump() if hasattr(constraints, "dict") else constraints
    city = constraints_dict.get("city") or "any city in India"
    # Set date to today if not present
    date = constraints_dict.get("date") or datetime.date.today().isoformat()
    days = constraints_dict.get("days") or 1
    budget = constraints_dict.get("budget_per_person") or "any"
    interests = constraints_dict.get("interests") or "none"
    query = (
        f"Hotels in {city} check-in on {date} for {days} night(s), "
        f"budget {budget}, interests: {interests}. "
        "Return hotel name, rating, price per night, distance from center, and amenities."
    )
    print("Hotel search query:", query)

    search_result = tavily_tool.invoke({"query": query})
    print("Raw search result:", search_result)

    llm_input = {"search_results": search_result}

    try:
        hotel_options = hotel_chain.invoke(llm_input)
        print("LLM hotel options raw output:", hotel_options)
        hotel_options = getattr(hotel_options, "content", hotel_options)
        print("LLM hotel options content:", hotel_options)
        hotel_options_list = json.loads(hotel_options)
        hotel_options = [HotelOption(**item) for item in hotel_options_list]
    except Exception as e:
        print("Hotel parse error:", e)
        hotel_options = []

    return {
        "hotel_options": hotel_options
    }

# %%
# Define itinerary node
def itinerary_node(state: PlannerState) -> PlannerState:
    constraints = state.get("constraints")
    if not constraints:
        raise ValueError("Constraints are required in the state for itinerary planning.")

    # Prepare a query for Tavily based on constraints
    constraints_dict = constraints.model_dump() if hasattr(constraints, "dict") else constraints
    city = constraints_dict.get("city") or "any city in India"
    days = constraints_dict.get("days") or 1
    interests = constraints_dict.get("interests") or "none"
    query = (
        f"Tourist attractions and activities in {city} for a {days}-day trip. "
        f"Interests: {interests}. Suggest morning, afternoon, and evening activities for each day."
    )
    print("Itinerary search query:", query)

    # Call Tavily tool to get search results
    search_result = tavily_tool.invoke({"query": query})
    print("Raw itinerary search result:", search_result)

    # Prepare input for LLM
    constraints_str = (
        json.dumps(constraints_dict, indent=2)
        if isinstance(constraints_dict, dict)
        else str(constraints_dict)
    )
    llm_input = {
        "search_results": search_result,
        "constraints": constraints_str
    }

    try:
        itinerary = itinerary_chain.invoke(llm_input)
        print(f"LLM itinerary raw output: {itinerary}")
        itinerary_content = getattr(itinerary, "content", itinerary)
        print(f"LLM itinerary content: {itinerary_content}")
        itinerary_list = json.loads(itinerary_content)
        print(f"Parsed itinerary_list: {itinerary_list}")
        if not isinstance(itinerary_list, list):
            raise ValueError("LLM did not return a JSON array.")
        itinerary = [ItineraryItem(**item) for item in itinerary_list]
    except Exception as e:
        print("Itinerary parse error:", e)
        itinerary = []

    return {
        "itinerary": itinerary
    }

# %%
# Define prompt templates and chains for final plan summarization# For full travel plan.
final_plan_prompt_template_travel_plan = """
You are an expert travel assistant that summarizes the final travel plan based on user constraints, transport options, hotel options, and itinerary.
Your response must be a summarized text containing the final travel plan details with the following sections:
1. Overview: A brief summary of the trip including origin, destination, dates, duration, budget, and interests.
2. Transport Options: A summary of the selected transport options including provider, mode, depart, arrive, duration, price, and notes.
3. Hotel Options: STRICTLY list and describe ONLY the hotel options provided below. DO NOT invent, generalize, or add any hotels or details not present in the hotel options list. For each hotel, include its name, rating, price, distance from center, amenities, and notes exactly as given.
4. Itinerary: A day-wise breakdown of the itinerary including morning, afternoon, evening activities and notes.
5. Estimated Total Cost: A summary of the estimated total cost for transport and hotel per person and itinerary activities.

User constraints:
{constraints}
Transport options:
{transport_options}
Hotel options:
{hotel_options}
Itinerary:
{itinerary}

Summarize the final travel plan in a clear and concise manner in a markdown format.
"""

# For transport only
final_plan_prompt_template_transport_only = """
You are an expert travel assistant. Summarize ONLY the transport options for the user's travel request, based on the user constraints and transport options below.
Do NOT include hotel or itinerary information. The output must be a summarized text containing the transport details with the following sections:
1. Overview: A brief summary of the trip including origin, destination, dates, duration, budget, and interests.
2. Transport Options: A summary of the selected transport options including mode, depart, arrive, duration, price, and notes.

User constraints:
{constraints}
Transport options:
{transport_options}

Summarize the available transport options in a clear and concise manner in a markdown format.
"""

# For hotel only
final_plan_prompt_template_hotel_only = """
You are an expert travel assistant. Summarize ONLY the hotel options for the user's travel request, based on the user constraints and hotel options below.
Do NOT include transport or itinerary information. The output must be a summarized text containing the hotel details with the following sections:
1. Overview: A brief summary of the trip including destination, dates, duration, budget, and interests.
2. Hotel Options: STRICTLY list and describe ONLY the hotel options provided below.

User constraints:
{constraints}
Hotel options:
{hotel_options}

Summarize the available hotel options in a clear and concise manner in a markdown format.
"""

# %%
# Define the summarizer node
def summarizer_node(state: PlannerState) -> PlannerState:
    constraints = state.get("constraints")
    transport_options = state.get("transport_options", [])
    hotel_options = state.get("hotel_options", [])
    itinerary = state.get("itinerary", [])
    intent = state.get("intent")

    if not constraints:
        raise ValueError("Constraints are required in the state for final plan summarization.")

    # Select prompt based on intent
    if intent == "transport_only":
        if not transport_options:
            return {
                "goal": state["goal"],
                "intent": intent,
                "constraints": constraints,
                "transport_options": transport_options,
                "hotel_options": hotel_options,
                "itinerary": itinerary,
                "final_plan": {"message": "No transport options were found."}
            }
        prompt = PromptTemplate(
            input_variables=["constraints", "transport_options"],
            template=final_plan_prompt_template_transport_only
        )
        llm_input = {
            "constraints": constraints,
            "transport_options": transport_options,
        }
    elif intent == "hotel_only":
        if not hotel_options:
            return {
                "goal": state["goal"],
                "intent": intent,
                "constraints": constraints,
                "transport_options": transport_options,
                "hotel_options": hotel_options,
                "itinerary": itinerary,
                "final_plan": {"message": "No hotel options were found."}
            }
        prompt = PromptTemplate(
            input_variables=["constraints", "hotel_options"],
            template=final_plan_prompt_template_hotel_only
        )
        llm_input = {
            "constraints": constraints,
            "hotel_options": hotel_options,
        }
    else:  # travel_plan or fallback
        prompt = PromptTemplate(
            input_variables=["constraints", "transport_options", "hotel_options", "itinerary"],
            template=final_plan_prompt_template_travel_plan
        )
        llm_input = {
            "constraints": constraints,
            "transport_options": transport_options,
            "hotel_options": hotel_options,
            "itinerary": itinerary,
        }

    final_plan_chain = prompt | llm

    try:
        final_plan_summary = final_plan_chain.invoke(llm_input)
        print(f"Final plan summary raw output: {final_plan_summary}")
    except Exception as e:
        print("Final plan summarization parse error:", e)
        final_plan_summary = {"message": "Could not generate final plan summary."}

    return {
        "goal": state["goal"],
        "intent": intent,
        "constraints": constraints,
        "transport_options": transport_options,
        "hotel_options": hotel_options,
        "itinerary": itinerary,
        "final_plan": final_plan_summary
    }

# %%
# Build and complile the state graph
builder = StateGraph(PlannerState)

# Add nodes
builder.add_node("supervisor", supervisor_node)
builder.add_node("planner", planner_node)
builder.add_node("end_unrelated", end_unrelated_node)
builder.add_node("transport", transport_node)
builder.add_node("hotel", hotel_node)
builder.add_node("itinerary", itinerary_node)
builder.add_node("final_summarizer", summarizer_node)

# Add edges
builder.add_edge(START, "supervisor")
builder.add_conditional_edges("supervisor", supervisor_gate, {
    "plan": "planner",
    "unrelated": "end_unrelated"
})
# builder.add_edge("planner", END)
builder.add_edge("transport", "final_summarizer")
builder.add_edge("hotel", "final_summarizer")
builder.add_edge("itinerary", "final_summarizer")
builder.add_edge("final_summarizer", END)
builder.add_edge("end_unrelated", END)

# Compile the graph
graph = builder.compile()

# %%
# Test the graph with a travel planning goal
input_text = "Plan a 3-day trip to Goa for two adults,and one child from Asansol by train and we need a 3-star hotel with breakfast included"
initial_state = {
    "goal": input_text,
    "intent": None,
    "final_plan": None
}
result = graph.invoke(initial_state)
print(result)
# Out:
# Supervisor raw output: travel_plan
# {
#   "origin": "Asansol",
#   "city": "Goa",
#   "date": null,
#   "return_date": null,
#   "days": 3,
#   "budget_per_person": null,
#   "interests": null,
#   "transport_constraints": {
#     "mode": "train",
#     "adults": 2,
#     "children": 1
#   },
#   "hotel_constraints": {
#     "star_rating": 3,
#     "amenities": "breakfast included"
#   }
# }
# In hotel node
# Hotel search query: Hotels in Goa check-in on 2025-09-19 for 3 night(s), budget any, interests: none. Return hotel name, rating, price per night, distance from center, and amenities.
# Itinerary search query: Tourist attractions and activities in Goa for a 3-day trip. Interests: none. Suggest morning, afternoon, and evening activities for each day.
# In transport node
# Transport search query: Transport options from Asansol to Goa on 2025-09-19 for 3 day(s), budget any, interests: none. Return provider, mode, depart, arrive, duration in minutes, price per person, and notes.
# Raw itinerary search result: {'query': 'Tourist attractions and activities in Goa for a 3-day trip. Interests: none. Suggest morning, afternoon, and evening activities for each day.', 'follow_up_questions': None, 'answer': None, 'images': [], 'results': [{'url': 'https://www.tripadvisor.com/AttractionProductReview-g297604-d19198440-Goa_Getaway_3_Day_Private_Tour_of_Beaches_and_Monuments-Goa.html', 'title': '2025 Goa Getaway: 3-Day Private Tour of Beaches and Monuments', 'content': "Explore the Aguada Fort, commanding the mouth of the Mondovi River, and delight in an evening cruise over the serene waters. Immerse yourself in Goa's scenic", 'score': 0.90692574, 'raw_content': None}, {'url': 'https://www.expedia.com/Things-To-Do-In-Goa.d6049928.Travel-Guide-Activities', 'title': 'Things to Do in Goa in 2025 | Expedia', 'content': 'Full-Day Tour Old Goa Dudhsagar Falls and Spice PlantationOpens in new tab Private 2-Day Tour to The Taj Mahal and Agra with Both Side Commercial Flig...Opens in new tab ### Goa: 3-Day Tour with Panjim, Beaches, and Aguda Nightlife Goa: 3-Day Tour with Panjim, Beaches, and Aguda NightlifeOpens in new tab Highlights of South Goa with Spice Plantation Tour (Guided Fullday Tour by ...Opens in new tab Full-Day Tour Old Goa Dudhsagar Falls and Spice PlantationOpens in new tab Old Goa Heritage & Culture E-Bike TourOpens in new tab Full-Day Tour Old Goa Dudhsagar Falls and Spice PlantationOpens in new tab Taj Mahal and Agra Overnight Tour from Goa with Return FlightsOpens in new tab', 'score': 0.90102744, 'raw_content': None}, {'url': 'https://www.tripadvisor.com/Attractions-g297604-Activities-Goa.html', 'title': 'THE 15 BEST Things to Do in Goa (2025) - Must-See Attractions', 'content': 'Check out must-see sights and activities: Palolem Beach, Baga Beach, Beaches, Nature and Wildlife Tours. For personalized recommendations, try our AI trip-', 'score': 0.89501935, 'raw_content': None}, {'url': 'https://www.getyourguide.com/goa-l825/', 'title': 'The BEST Goa Tours and Things to Do in 2025 - GetYourGuide', 'content': "* Explore Goa How GetYourGuide ranks activities Activities on the GetYourGuide marketplace are ranked by a combination of factors including popularity, diversity, availability, customer rating, cancellation rate, performance over time, and amount of revenue generated. ### Panaji: Heritage Walk through Goa's Latin Quarter * 10 hours • Pickup available ### Goa: Guided Walking Tour of Panjim's Colonial History ### Goa: Dinner Cruise Party with Hotel Transfer Option * 3 - 4 hours • Pickup available ### Goa: Triple Deck Family Dinner Cruise and Performances * 4 hours • Pickup available ### Old Goa: Walking Tour of Heritage Churches ### Goa Shore excursions : All inclusive Small Group tour ### Goa: Cruise with Hotel Transfers, 2 Beers, DJ, and Dinner", 'score': 0.85825616, 'raw_content': None}, {'url': 'https://www.youtube.com/watch?v=uq3WoatR-Nc', 'title': 'Top 10 Best Places to Visit in GOA 2025 | India Travel Guide', 'content': 'Top 10 Best Places to Visit in GOA 2025 | India Travel Guide\nTRIP XTREME\n98700 subscribers\n39 likes\n6944 views\n13 Oct 2024\nDive into the Top 10 Best Places to Visit in Goa in 2025 with this exciting India travel guide! Famous for its golden beaches, vibrant nightlife, and Portuguese heritage, Goa is the perfect mix of relaxation and adventure. From scenic beaches and historic churches to bustling flea markets, these must-visit spots showcase the very best of Goa. Whether you’re a beach lover, a history enthusiast, or a foodie, Goa has something unique for everyone. Watch now and start planning your unforgettable Goan getaway!\n👉 Subscribe to our channel and turn on 🔔 http://bit.ly/travel-xtreme\n\nCHAPTERS:\n0:00 Intro\n0:35 #10 Mahadev Temple\n1:11 #9 Braganza House\n2:22 #8 Church of Our Lady of the Immaculate Conception\n3:28 #7 Anjuna Market\n4:27 #6 Dudhsagar Falls\n5:41 #5 Basilica de Bom Jesus\n7:10 #4 Portuguese-Indian Restaurants\n8:33 #3 Tanshikar\'s Working Sp ...
# Raw search result: {'query': 'Hotels in Goa check-in on 2025-09-19 for 3 night(s), budget any, interests: none. Return hotel name, rating, price per night, distance from center, and amenities.', 'follow_up_questions': None, 'answer': None, 'images': [], 'results': [{'url': 'https://www.tripadvisor.com/Hotels-g297604-Goa-Hotels.html', 'title': 'THE 10 BEST Hotels in Goa, India 2025 (from $11) - Tripadvisor', 'content': 'Popular hotels by the beach in Goa include The Astor - All Suites Hotel Candolim Goa, Summit Calangute Resort And Spa, and The Crescent.', 'score': 0.78413767, 'raw_content': None}, {'url': 'https://www.agoda.com/w-goa/hotel/goa-in.html', 'title': 'W Goa, Goa | 2025 Updated Prices, Deals - Agoda.com', 'content': 'Experience the epitome of luxury at W Goa without breaking the bank. With an average price of $415 per room, this five-star hotel offers an unparalleled', 'score': 0.7178241, 'raw_content': None}, {'url': 'https://www.expedia.com/Destinations-In-Goa.d6049928.Hotel-Destinations', 'title': 'Top Goa Hotels: 2025 Best Hotels in Goa - Expedia', 'content': '# Find hotels in Goa for you "This was a fantastic stay at Goa Radisson Blu, we enjoyed the quietness, serenity, private beach access and staff service. ## Find out more about Goa ## Find out more about Goa Whether you\'re seeking a family-friendly getaway, a serene beach escape, or a business-friendly stay, Goa\'s hotels cater to all preferences. ### Where to stay in Goa Goa is the perfect destination for beach lovers and culture enthusiasts alike, offering a variety of activities such as visiting vibrant public markets, enjoying thrilling casino experiences, and exploring the great outdoors. * **The most and least expensive months on average to stay in a hotel:** The cheapest months to stay in Goa are May to June and September, where the prices are slightly lower.', 'score': 0.6811549, 'raw_content': None}, {'url': 'https://www.tripadvisor.com/Hotel_Review-g306995-d5485906-Reviews-Hard_Rock_Hotel_Goa-Calangute_North_Goa_District_Goa.html', 'title': 'HARD ROCK HOTEL GOA - Updated 2025 Prices & Reviews ...', 'content': 'Hard Rock Hotel Goa, popular for its lively atmosphere and central location near Calangute Beach, is a hit for many travelers.', 'score': 0.6097339, 'raw_content': None}, {'url': 'https://www.booking.com/region/in/goa.html', 'title': 'Search the TOP Hotels in Goa, India - Book Today', 'content': 'How much is a hotel in Goa for this weekend? The average price per night for a 3-star hotel in Goa this weekend is $47 or $81 for a 4-star hotel. Looking', 'score': 0.55449516, 'raw_content': None}], 'response_time': 1.84, 'request_id': '6d39d0f6-0990-4efc-8ea1-09f409899c6d'}
# Raw transport search result: {'query': 'Transport options from Asansol to Goa on 2025-09-19 for 3 day(s), budget any, interests: none. Return provider, mode, depart, arrive, duration in minutes, price per person, and notes.', 'follow_up_questions': None, 'answer': None, 'images': [], 'results': [{'url': 'https://www.rome2rio.com/s/%C4%80sansol/Goa-Philippines', 'title': 'Āsansol to Goa - 6 ways to travel via train, plane, taxi, and bus', 'content': 'The cheapest way to get from Āsansol to Goa costs only $301, and the quickest way takes just 17¼ hours. Find the travel option that best suits you.', 'score': 0.72348577, 'raw_content': None}, {'url': 'https://www.makemytrip.com/routeplanner/asansol-goa.html', 'title': 'Asansol to Goa - Multiple Options To Reach By Train, Flight', 'content': 'The recommended way to reach Goa from Asansol is by Train which would take approximately 40 hours. The fastest way to reach Goa from Asansol is by Train', 'score': 0.71305263, 'raw_content': None}, {'url': 'https://www.rome2rio.com/s/%C4%80sansol/Goa-India', 'title': 'Āsansol to Goa - 8 ways to travel via train, plane, bus, and car', 'content': 'The cheapest way to get from Āsansol to Goa is to train and bus which costs ₹1,600 - ₹15,000 and takes 46h 20m. ... What is the fastest way to get from Āsansol to', 'score': 0.6551821, 'raw_content': None}, {'url': 'https://www.goibibo.com/trains/asansol-to-goa-trains/', 'title': 'Asansol to Goa Trains | Book from 1 Trains - Goibibo', 'content': 'On a weekly basis, there are trains running between Asansol to Goa.To get accurate information regarding Asansol to Goa trains, Asansol Goa Railway Timetable,', 'score': 0.57236487, 'raw_content': None}, {'url': 'https://www.ixigo.com/by-train-rail/asansol-to-goa-by-train', 'title': 'Asansol to Goa Trains | Book from 0 Trains, Fare, Time Table', 'content': 'Book Asansol to Goa train tickets online on ixigo. Check 0 trains from Asansol to Goa with ticket price, seat availability, arrival & departure timetable.', 'score': 0.55391616, 'raw_content': None}], 'response_time': 1.99, 'request_id': 'ac9f34e5-5379-413e-ba9f-16b72bc155ba'}
# LLM itinerary raw output: content='[\n  {\n    "day": 1,\n    "morning": "Explore the Aguada Fort, commanding the mouth of the Mondovi River.",\n    "afternoon": "Visit the Palolem Beach for a relaxing afternoon.",\n    "evening": "Delight in an evening cruise over the serene waters.",\n    "notes": "Remember to pack beach essentials."\n  },\n  {\n    "day": 2,\n    "morning": "Visit the Old Goa Heritage & Culture for a guided E-Bike Tour.",\n    "afternoon": "Experience the Full-Day Tour Old Goa Dudhsagar Falls and Spice Plantation.",\n    "evening": "Enjoy the nightlife at Aguda.",\n    "notes": "Carry comfortable shoes for the bike tour."\n  },\n  {\n    "day": 3,\n    "morning": "Explore the Baga Beach and engage in Nature and Wildlife Tours.",\n    "afternoon": "Visit the Tanshikar\'s Working Spice Farm.",\n    "evening": "End the day with a Dinner Cruise Party with Hotel Transfer Option.",\n    "notes": "Don\'t forget to buy some spices from the spice farm."\n  }\n]' additional_kwargs={'refusal': None} response_metadata={'token_usage': {'completion_tokens': 243, 'prompt_tokens': 1543, 'total_tokens': 1786, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-4-0613', 'system_fingerprint': None, 'id': 'chatcmpl-CHNKqP8GSoMDVMYktBHSxgd9u1dde', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None} id='run--e7e9489e-3556-4666-9979-88cd3d95a8af-0' usage_metadata={'input_tokens': 1543, 'output_tokens': 243, 'total_tokens': 1786, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}
# LLM itinerary content: [
#   {
#     "day": 1,
#     "morning": "Explore the Aguada Fort, commanding the mouth of the Mondovi River.",
#     "afternoon": "Visit the Palolem Beach for a relaxing afternoon.",
#     "evening": "Delight in an evening cruise over the serene waters.",
#     "notes": "Remember to pack beach essentials."
#   },
#   {
#     "day": 2,
#     "morning": "Visit the Old Goa Heritage & Culture for a guided E-Bike Tour.",
#     "afternoon": "Experience the Full-Day Tour Old Goa Dudhsagar Falls and Spice Plantation.",
#     "evening": "Enjoy the nightlife at Aguda.",
#     "notes": "Carry comfortable shoes for the bike tour."
#   },
#   {
#     "day": 3,
#     "morning": "Explore the Baga Beach and engage in Nature and Wildlife Tours.",
#     "afternoon": "Visit the Tanshikar's Working Spice Farm.",
#     "evening": "End the day with a Dinner Cruise Party with Hotel Transfer Option.",
#     "notes": "Don't forget to buy some spices from the spice farm."
#   }
# ]
# Parsed itinerary_list: [{'day': 1, 'morning': 'Explore the Aguada Fort, commanding the mouth of the Mondovi River.', 'afternoon': 'Visit the Palolem Beach for a relaxing afternoon.', 'evening': 'Delight in an evening cruise over the serene waters.', 'notes': 'Remember to pack beach essentials.'}, {'day': 2, 'morning': 'Visit the Old Goa Heritage & Culture for a guided E-Bike Tour.', 'afternoon': 'Experience the Full-Day Tour Old Goa Dudhsagar Falls and Spice Plantation.', 'evening': 'Enjoy the nightlife at Aguda.', 'notes': 'Carry comfortable shoes for the bike tour.'}, {'day': 3, 'morning': 'Explore the Baga Beach and engage in Nature and Wildlife Tours.', 'afternoon': "Visit the Tanshikar's Working Spice Farm.", 'evening': 'End the day with a Dinner Cruise Party with Hotel Transfer Option.', 'notes': "Don't forget to buy some spices from the spice farm."}]
# LLM hotel options raw output: content='[\n  {\n    "name": "The Astor - All Suites Hotel Candolim Goa",\n    "rating": null,\n    "price_per_night": 0,\n    "distance_from_center_km": null,\n    "amenities": [],\n    "notes": null\n  },\n  {\n    "name": "Summit Calangute Resort And Spa",\n    "rating": null,\n    "price_per_night": 0,\n    "distance_from_center_km": null,\n    "amenities": [],\n    "notes": null\n  },\n  {\n    "name": "The Crescent",\n    "rating": null,\n    "price_per_night": 0,\n    "distance_from_center_km": null,\n    "amenities": [],\n    "notes": null\n  },\n  {\n    "name": "W Goa",\n    "rating": 5,\n    "price_per_night": 415,\n    "distance_from_center_km": null,\n    "amenities": [],\n    "notes": null\n  },\n  {\n    "name": "Goa Radisson Blu",\n    "rating": null,\n    "price_per_night": 0,\n    "distance_from_center_km": null,\n    "amenities": ["private beach access"],\n    "notes": null\n  },\n  {\n    "name": "Hard Rock Hotel Goa",\n    "rating": null,\n    "price_per_night": 0,\n    "distance_from_center_km": null,\n    "amenities": [],\n    "notes": "popular for its lively atmosphere and central location near Calangute Beach"\n  }\n]' additional_kwargs={'refusal': None} response_metadata={'token_usage': {'completion_tokens': 334, 'prompt_tokens': 847, 'total_tokens': 1181, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-4-0613', 'system_fingerprint': None, 'id': 'chatcmpl-CHNKrIWCaYh6VNWzLXNesIErRj1lW', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None} id='run--51235fa9-4a00-4184-8030-a0de9b42a6ed-0' usage_metadata={'input_tokens': 847, 'output_tokens': 334, 'total_tokens': 1181, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}
# LLM hotel options content: [
#   {
#     "name": "The Astor - All Suites Hotel Candolim Goa",
#     "rating": null,
#     "price_per_night": 0,
#     "distance_from_center_km": null,
#     "amenities": [],
#     "notes": null
#   },
#   {
#     "name": "Summit Calangute Resort And Spa",
#     "rating": null,
#     "price_per_night": 0,
#     "distance_from_center_km": null,
#     "amenities": [],
#     "notes": null
#   },
#   {
#     "name": "The Crescent",
#     "rating": null,
#     "price_per_night": 0,
#     "distance_from_center_km": null,
#     "amenities": [],
#     "notes": null
#   },
#   {
#     "name": "W Goa",
#     "rating": 5,
#     "price_per_night": 415,
#     "distance_from_center_km": null,
#     "amenities": [],
#     "notes": null
#   },
#   {
#     "name": "Goa Radisson Blu",
#     "rating": null,
#     "price_per_night": 0,
#     "distance_from_center_km": null,
#     "amenities": ["private beach access"],
#     "notes": null
#   },
#   {
#     "name": "Hard Rock Hotel Goa",
#     "rating": null,
#     "price_per_night": 0,
#     "distance_from_center_km": null,
#     "amenities": [],
#     "notes": "popular for its lively atmosphere and central location near Calangute Beach"
#   }
# ]
# LLM transport options raw output: content='[\n  {\n    "provider": "rome2rio.com",\n    "mode": "train, plane, taxi, bus",\n    "depart": "Asansol",\n    "arrive": "Goa",\n    "duration_min": "1035",\n    "price_per_person": "$301",\n    "notes": "The quickest way to get from Āsansol to Goa"\n  },\n  {\n    "provider": "makemytrip.com",\n    "mode": "Train",\n    "depart": "Asansol",\n    "arrive": "Goa",\n    "duration_min": "2400",\n    "price_per_person": null,\n    "notes": "The recommended way to reach Goa from Asansol is by Train"\n  },\n  {\n    "provider": "rome2rio.com",\n    "mode": "train, bus",\n    "depart": "Asansol",\n    "arrive": "Goa",\n    "duration_min": "2780",\n    "price_per_person": "₹1,600 - ₹15,000",\n    "notes": "The cheapest way to get from Āsansol to Goa is to train and bus"\n  },\n  {\n    "provider": "goibibo.com",\n    "mode": "Train",\n    "depart": "Asansol",\n    "arrive": "Goa",\n    "duration_min": null,\n    "price_per_person": null,\n    "notes": "On a weekly basis, there are trains running between Asansol to Goa"\n  },\n  {\n    "provider": "ixigo.com",\n    "mode": "Train",\n    "depart": "Asansol",\n    "arrive": "Goa",\n    "duration_min": null,\n    "price_per_person": null,\n    "notes": "Book Asansol to Goa train tickets online on ixigo"\n  }\n]' additional_kwargs={'refusal': None} response_metadata={'token_usage': {'completion_tokens': 395, 'prompt_tokens': 763, 'total_tokens': 1158, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-4-0613', 'system_fingerprint': None, 'id': 'chatcmpl-CHNKr0ToqFo7lPM2wtCEJAFHERrJD', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None} id='run--e8960e06-38e0-4cc9-bb05-bfe930d7da98-0' usage_metadata={'input_tokens': 763, 'output_tokens': 395, 'total_tokens': 1158, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}
# LLM transport options content: [
#   {
#     "provider": "rome2rio.com",
#     "mode": "train, plane, taxi, bus",
#     "depart": "Asansol",
#     "arrive": "Goa",
#     "duration_min": "1035",
#     "price_per_person": "$301",
#     "notes": "The quickest way to get from Āsansol to Goa"
#   },
#   {
#     "provider": "makemytrip.com",
#     "mode": "Train",
#     "depart": "Asansol",
#     "arrive": "Goa",
#     "duration_min": "2400",
#     "price_per_person": null,
#     "notes": "The recommended way to reach Goa from Asansol is by Train"
#   },
#   {
#     "provider": "rome2rio.com",
#     "mode": "train, bus",
#     "depart": "Asansol",
#     "arrive": "Goa",
#     "duration_min": "2780",
#     "price_per_person": "₹1,600 - ₹15,000",
#     "notes": "The cheapest way to get from Āsansol to Goa is to train and bus"
#   },
#   {
#     "provider": "goibibo.com",
#     "mode": "Train",
#     "depart": "Asansol",
#     "arrive": "Goa",
#     "duration_min": null,
#     "price_per_person": null,
#     "notes": "On a weekly basis, there are trains running between Asansol to Goa"
#   },
#   {
#     "provider": "ixigo.com",
#     "mode": "Train",
#     "depart": "Asansol",
#     "arrive": "Goa",
#     "duration_min": null,
#     "price_per_person": null,
#     "notes": "Book Asansol to Goa train tickets online on ixigo"
#   }
# ]
# Final plan summary raw output: content="# Final Travel Plan\n\n## 1. Overview\nThe trip is planned for a family of 2 adults and 1 child from Asansol to Goa for a duration of 3 days. The mode of transport preferred is train and the hotel preference is a 3-star rating with breakfast included. The exact dates of travel are yet to be decided.\n\n## 2. Transport Options\nThe recommended way to reach Goa from Asansol is by Train. However, the quickest way to get from Asansol to Goa is a combination of train, plane, taxi, and bus, which takes approximately 1035 minutes and costs $301 per person. The cheapest way to get from Asansol to Goa is to take a train and bus, which takes around 2780 minutes and costs between ₹1,600 - ₹15,000 per person. \n\n## 3. Hotel Options\nThe hotel options provided are:\n\n- The Astor - All Suites Hotel Candolim Goa: Price and other details are not provided.\n- Summit Calangute Resort And Spa: Price and other details are not provided.\n- The Crescent: Price and other details are not provided.\n- W Goa: A 5-star hotel priced at $415 per night. Other details are not provided.\n- Goa Radisson Blu: Offers amenities like private beach access. Price and other details are not provided.\n- Hard Rock Hotel Goa: Known for its lively atmosphere and central location near Calangute Beach. Price and other details are not provided.\n\n## 4. Itinerary\n- Day 1: Morning exploration of the Aguada Fort, afternoon relaxation at the Palolem Beach, and an evening cruise over the serene waters. Remember to pack beach essentials.\n- Day 2: Morning guided E-Bike Tour at the Old Goa Heritage & Culture, afternoon tour of Old Goa Dudhsagar Falls and Spice Plantation, and evening enjoyment of the nightlife at Aguda. Carry comfortable shoes for the bike tour.\n- Day 3: Morning engagement in Nature and Wildlife Tours at the Baga Beach, afternoon visit to the Tanshikar's Working Spice Farm, and ending the day with a Dinner Cruise Party with Hotel Transfer Option. Don't forget to buy some spices from the spice farm.\n\n## 5. Estimated Total Cost\nThe total cost per person for transport ranges from ₹1,600 - ₹15,000 or $301 depending on the chosen option. The hotel costs and itinerary activity costs are not provided. Therefore, the total cost cannot be estimated at this time." additional_kwargs={'refusal': None} response_metadata={'token_usage': {'completion_tokens': 519, 'prompt_tokens': 953, 'total_tokens': 1472, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-4-0613', 'system_fingerprint': None, 'id': 'chatcmpl-CHNL5tvlR4n1WTpUx5Y96DgO6KoAD', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None} id='run--843dbce5-e290-403f-9dd4-772e4a326e4f-0' usage_metadata={'input_tokens': 953, 'output_tokens': 519, 'total_tokens': 1472, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}
# {'goal': 'Plan a 3-day trip to Goa for two adults,and one child from Asansol by train and we need a 3-star hotel with breakfast included', 'intent': 'travel_plan', 'constraints': Constraints(origin='Asansol', city='Goa', date=None, return_date=None, days=3, budget_per_person=None, interests=None, transport_constraints={'mode': 'train', 'adults': 2, 'children': 1}, hotel_constraints={'star_rating': 3, 'amenities': 'breakfast included'}), 'transport_options': [TransportOption(mode='train, plane, taxi, bus', depart='Asansol', arrive='Goa', duration_min='1035', price_per_person='$301', notes='The quickest way to get from Āsansol to Goa'), TransportOption(mode='Train', depart='Asansol', arrive='Goa', duration_min='2400', price_per_person=None, notes='The recommended way to reach Goa from Asansol is by Train'), TransportOption(mode='train, bus', depart='Asansol', arrive='Goa', duration_min='2780', price_per_person='₹1,600 - ₹15,000', notes='The cheapest way to get from Āsansol to Goa is to train and bus'), TransportOption(mode='Train', depart='Asansol', arrive='Goa', duration_min=None, price_per_person=None, notes='On a weekly basis, there are trains running between Asansol to Goa'), TransportOption(mode='Train', depart='Asansol', arrive='Goa', duration_min=None, price_per_person=None, notes='Book Asansol to Goa train tickets online on ixigo')], 'hotel_options': [HotelOption(name='The Astor - All Suites Hotel Candolim Goa', rating=None, price_per_night=0.0, distance_from_center_km=None, amenities=[], notes=None), HotelOption(name='Summit Calangute Resort And Spa', rating=None, price_per_night=0.0, distance_from_center_km=None, amenities=[], notes=None), HotelOption(name='The Crescent', rating=None, price_per_night=0.0, distance_from_center_km=None, amenities=[], notes=None), HotelOption(name='W Goa', rating=5.0, price_per_night=415.0, distance_from_center_km=None, amenities=[], notes=None), HotelOption(name='Goa Radisson Blu', rating=None, price_per_night=0.0, distance_from_center_km=None, amenities=['private beach access'], notes=None), HotelOption(name='Hard Rock Hotel Goa', rating=None, price_per_night=0.0, distance_from_center_km=None, amenities=[], notes='popular for its lively atmosphere and central location near Calangute Beach')], 'itinerary': [ItineraryItem(day=1, morning='Explore the Aguada Fort, commanding the mouth of the Mondovi River.', afternoon='Visit the Palolem Beach for a relaxing afternoon.', evening='Delight in an evening cruise over the serene waters.', notes='Remember to pack beach essentials.'), ItineraryItem(day=2, morning='Visit the Old Goa Heritage & Culture for a guided E-Bike Tour.', afternoon='Experience the Full-Day Tour Old Goa Dudhsagar Falls and Spice Plantation.', evening='Enjoy the nightlife at Aguda.', notes='Carry comfortable shoes for the bike tour.'), ItineraryItem(day=3, morning='Explore the Baga Beach and engage in Nature and Wildlife Tours.', afternoon="Visit the Tanshikar's Working Spice Farm.", evening='End the day with a Dinner Cruise Party with Hotel Transfer Option.', notes="Don't forget to buy some spices from the spice farm.")], 'final_plan': AIMessage(content="# Final Travel Plan\n\n## 1. Overview\nThe trip is planned for a family of 2 adults and 1 child from Asansol to Goa for a duration of 3 days. The mode of transport preferred is train and the hotel preference is a 3-star rating with breakfast included. The exact dates of travel are yet to be decided.\n\n## 2. Transport Options\nThe recommended way to reach Goa from Asansol is by Train. However, the quickest way to get from Asansol to Goa is a combination of train, plane, taxi, and bus, which takes approximately 1035 minutes and costs $301 per person. The cheapest way to get from Asansol to Goa is to take a train and bus, which takes around 2780 minutes and costs between ₹1,600 - ₹15,000 per person. \n\n## 3. Hotel Options\nThe hotel options provided are:\n\n- The Astor - All Suites Hotel Candolim Goa: Price and other details ar ...

# %%
if result.get("final_plan"):
    if isinstance(result["final_plan"], dict) and "message" in result["final_plan"]:
        display(Markdown(result["final_plan"]["message"]))
    else:
        display(Markdown(result["final_plan"].content))
# Out:
# # Final Travel Plan
#
# ## 1. Overview
# The trip is planned for a family of 2 adults and 1 child from Asansol to Goa for a duration of 3 days. The mode of transport preferred is train and the hotel preference is a 3-star rating with breakfast included. The exact dates of travel are yet to be decided.
#
# ## 2. Transport Options
# The recommended way to reach Goa from Asansol is by Train. However, the quickest way to get from Asansol to Goa is a combination of train, plane, taxi, and bus, which takes approximately 1035 minutes and costs $301 per person. The cheapest way to get from Asansol to Goa is to take a train and bus, which takes around 2780 minutes and costs between ₹1,600 - ₹15,000 per person.
#
# ## 3. Hotel Options
# The hotel options provided are:
#
# - The Astor - All Suites Hotel Candolim Goa: Price and other details are not provided.
# - Summit Calangute Resort And Spa: Price and other details are not provided.
# - The Crescent: Price and other details are not provided.
# - W Goa: A 5-star hotel priced at $415 per night. Other details are not provided.
# - Goa Radisson Blu: Offers amenities like private beach access. Price and other details are not provided.
# - Hard Rock Hotel Goa: Known for its lively atmosphere and central location near Calangute Beach. Price and other details are not provided.
#
# ## 4. Itinerary
# - Day 1: Morning exploration of the Aguada Fort, afternoon relaxation at the Palolem Beach, and an evening cruise over the serene waters. Remember to pack beach essentials.
# - Day 2: Morning guided E-Bike Tour at the Old Goa Heritage & Culture, afternoon tour of Old Goa Dudhsagar Falls and Spice Plantation, and evening enjoyment of the nightlife at Aguda. Carry comfortable shoes for the bike tour.
# - Day 3: Morning engagement in Nature and Wildlife Tours at the Baga Beach, afternoon visit to the Tanshikar's Working Spice Farm, and ending the day with a Dinner Cruise Party with Hotel Transfer Option. Don't forget to buy some spices from the spice farm.
#
# ## 5. Estimated Total Cost
# The total cost per person for transport ranges from ₹1,600 - ₹15,000 or $301 depending on the chosen option. The hotel costs and itinerary activity costs are not provided. Therefore, the total cost cannot be estimated at this time.

# %%
# Test the graph for transport only
input_text= "I want to go to Goa from Asansol on 2nd October, 2025. What are the convenient transport options?"
result = graph.invoke({"goal": input_text})
print(result)
# Out:
# Supervisor raw output: transport_only
# {
#   "origin": "Asansol",
#   "city": "Goa",
#   "date": "2025-10-02",
#   "return_date": null,
#   "days": null,
#   "budget_per_person": null,
#   "interests": null,
#   "transport_constraints": null,
#   "hotel_constraints": null
# }
# In transport node
# Transport search query: Transport options from Asansol to Goa on 2025-10-02 for 1 day(s), budget any, interests: none. Return provider, mode, depart, arrive, duration in minutes, price per person, and notes.
# Raw transport search result: {'query': 'Transport options from Asansol to Goa on 2025-10-02 for 1 day(s), budget any, interests: none. Return provider, mode, depart, arrive, duration in minutes, price per person, and notes.', 'follow_up_questions': None, 'answer': None, 'images': [], 'results': [{'url': 'https://www.rome2rio.com/s/%C4%80sansol/Goa-Philippines', 'title': 'Āsansol to Goa - 6 ways to travel via train, plane, taxi, and bus', 'content': 'The cheapest way to get from Āsansol to Goa costs only $301, and the quickest way takes just 17¼ hours. Find the travel option that best suits you.', 'score': 0.70531887, 'raw_content': None}, {'url': 'https://www.rome2rio.com/s/%C4%80sansol/Goa-India', 'title': 'Āsansol to Goa - 8 ways to travel via train, plane, bus, and car', 'content': 'The cheapest way to get from Āsansol to Goa is to train and bus which costs ₹1,600 - ₹15,000 and takes 46h 20m. ... What is the fastest way to get from Āsansol to', 'score': 0.64128816, 'raw_content': None}, {'url': 'https://www.goibibo.com/trains/asansol-to-goa-trains/', 'title': 'Asansol to Goa Trains | Book from 1 Trains - Goibibo', 'content': '... is 1641 KM and minimum travel time is 1 day 22 hrs 15 mins . From which all stations in Asansol we can board trains to Goa? Stations in Asansol where we can', 'score': 0.63804686, 'raw_content': None}, {'url': 'https://www.goibibo.com/trains/goa-to-asansol-trains/', 'title': 'Goa to Asansol Trains | Book from 1 Trains - Goibibo', 'content': '... is 1641 KM and minimum travel time is 1 day 23 hrs 26 mins . From which all stations in Goa we can board trains to Asansol? Stations in Goa where we can', 'score': 0.60049355, 'raw_content': None}, {'url': 'https://www.makemytrip.com/routeplanner/asansol-goa.html', 'title': 'Asansol to Goa - Multiple Options To Reach By Train, Flight', 'content': 'How long does it take to reach Goa from Asansol? It takes approximately 10 hours to reach Goa from Asansol by Train, Flight Via Kolkata.', 'score': 0.5993685, 'raw_content': None}], 'response_time': 2.17, 'request_id': '18c57e21-d090-490f-b37f-89973659d179'}
# LLM transport options raw output: content='[\n  {\n    "provider": "rome2rio",\n    "mode": "train, plane, taxi, bus",\n    "depart": "Asansol",\n    "arrive": "Goa",\n    "duration_min": "1035",\n    "price_per_person": "$301",\n    "notes": "The quickest way to get from Āsansol to Goa"\n  },\n  {\n    "provider": "rome2rio",\n    "mode": "train, bus",\n    "depart": "Asansol",\n    "arrive": "Goa",\n    "duration_min": "2780",\n    "price_per_person": "₹1,600 - ₹15,000",\n    "notes": "The cheapest way to get from Āsansol to Goa"\n  },\n  {\n    "provider": "Goibibo",\n    "mode": "train",\n    "depart": "Asansol",\n    "arrive": "Goa",\n    "duration_min": "2675",\n    "price_per_person": null,\n    "notes": null\n  },\n  {\n    "provider": "Goibibo",\n    "mode": "train",\n    "depart": "Goa",\n    "arrive": "Asansol",\n    "duration_min": "2816",\n    "price_per_person": null,\n    "notes": null\n  },\n  {\n    "provider": "MakeMyTrip",\n    "mode": "train, flight",\n    "depart": "Asansol",\n    "arrive": "Goa",\n    "duration_min": "600",\n    "price_per_person": null,\n    "notes": "Via Kolkata"\n  }\n]' additional_kwargs={'refusal': None} response_metadata={'token_usage': {'completion_tokens': 353, 'prompt_tokens': 772, 'total_tokens': 1125, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-4-0613', 'system_fingerprint': None, 'id': 'chatcmpl-CHND2f7Dwd9zq1MvJ9QJ71qV7dBRi', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None} id='run--dc1a83ce-1421-4731-944d-def6fcb33591-0' usage_metadata={'input_tokens': 772, 'output_tokens': 353, 'total_tokens': 1125, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}
# LLM transport options content: [
#   {
#     "provider": "rome2rio",
#     "mode": "train, plane, taxi, bus",
#     "depart": "Asansol",
#     "arrive": "Goa",
#     "duration_min": "1035",
#     "price_per_person": "$301",
#     "notes": "The quickest way to get from Āsansol to Goa"
#   },
#   {
#     "provider": "rome2rio",
#     "mode": "train, bus",
#     "depart": "Asansol",
#     "arrive": "Goa",
#     "duration_min": "2780",
#     "price_per_person": "₹1,600 - ₹15,000",
#     "notes": "The cheapest way to get from Āsansol to Goa"
#   },
#   {
#     "provider": "Goibibo",
#     "mode": "train",
#     "depart": "Asansol",
#     "arrive": "Goa",
#     "duration_min": "2675",
#     "price_per_person": null,
#     "notes": null
#   },
#   {
#     "provider": "Goibibo",
#     "mode": "train",
#     "depart": "Goa",
#     "arrive": "Asansol",
#     "duration_min": "2816",
#     "price_per_person": null,
#     "notes": null
#   },
#   {
#     "provider": "MakeMyTrip",
#     "mode": "train, flight",
#     "depart": "Asansol",
#     "arrive": "Goa",
#     "duration_min": "600",
#     "price_per_person": null,
#     "notes": "Via Kolkata"
#   }
# ]
# Final plan summary raw output: content='## Overview\nThe trip is planned from Asansol to Goa on the 2nd of October, 2025. The return date and duration of the stay are not specified. There are no specific budget constraints or interests mentioned for this trip.\n\n## Transport Options\n1. **Train, Plane, Taxi, Bus**: This is the quickest way to get from Asansol to Goa. The journey will take approximately 1035 minutes and the cost per person is $301.\n\n2. **Train, Bus**: This is the cheapest way to get from Asansol to Goa. The journey will take approximately 2780 minutes and the cost per person ranges from ₹1,600 to ₹15,000.\n\n3. **Train**: There is also an option to travel only by train from Asansol to Goa. The journey will take approximately 2675 minutes. The price for this option is not specified.\n\n4. **Train**: For the return journey from Goa to Asansol, the train is an option. The journey will take approximately 2816 minutes. The price for this option is not specified.\n\n5. **Train, Flight**: Another option is to travel by train and flight via Kolkata from Asansol to Goa. The journey will take approximately 600 minutes. The price for this option is not specified.' additional_kwargs={'refusal': None} response_metadata={'token_usage': {'completion_tokens': 269, 'prompt_tokens': 378, 'total_tokens': 647, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-4-0613', 'system_fingerprint': None, 'id': 'chatcmpl-CHNDD3DZwUob6Rpibgu0iauf2KFGA', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None} id='run--afcbb26d-3a81-4036-8013-e2af2ee916af-0' usage_metadata={'input_tokens': 378, 'output_tokens': 269, 'total_tokens': 647, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}
# {'goal': 'I want to go to Goa from Asansol on 2nd October, 2025. What are the convenient transport options?', 'intent': 'transport_only', 'constraints': Constraints(origin='Asansol', city='Goa', date='2025-10-02', return_date=None, days=None, budget_per_person=None, interests=None, transport_constraints=None, hotel_constraints=None), 'transport_options': [TransportOption(mode='train, plane, taxi, bus', depart='Asansol', arrive='Goa', duration_min='1035', price_per_person='$301', notes='The quickest way to get from Āsansol to Goa'), TransportOption(mode='train, bus', depart='Asansol', arrive='Goa', duration_min='2780', price_per_person='₹1,600 - ₹15,000', notes='The cheapest way to get from Āsansol to Goa'), TransportOption(mode='train', depart='Asansol', arrive='Goa', duration_min='2675', price_per_person=None, notes=None), TransportOption(mode='train', depart='Goa', arrive='Asansol', duration_min='2816', price_per_person=None, notes=None), TransportOption(mode='train, flight', depart='Asansol', arrive='Goa', duration_min='600', price_per_person=None, notes='Via Kolkata')], 'hotel_options': [], 'itinerary': [], 'final_plan': AIMessage(content='## Overview\nThe trip is planned from Asansol to Goa on the 2nd of October, 2025. The return date and duration of the stay are not specified. There are no specific budget constraints or interests mentioned for this trip.\n\n## Transport Options\n1. **Train, Plane, Taxi, Bus**: This is the quickest way to get from Asansol to Goa. The journey will take approximately 1035 minutes and the cost per person is $301.\n\n2. **Train, Bus**: This is the cheapest way to get from Asansol to Goa. The journey will take approximately 2780 minutes and the cost per person ranges from ₹1,600 to ₹15,000.\n\n3. **Train**: There is also an option to travel only by train from Asansol to Goa. The journey will take approximately 2675 minutes. The price for this option is not specified.\n\n4. **Train**: For the return journey from Goa to Asansol, the train is an option. The journey will take approximately 2816 minutes. The price for this option is not specified.\n\n5. **Train, Flight**: Another option is to travel by train and flight via Kolkata from Asansol to Goa. The journey will take approximately 600 minutes. The price for this option is not specified.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 269, 'prompt_tokens': 378, 'total_tokens': 647, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-4-0613', 'system_fingerprint': None, 'id': 'chatcmpl-CHNDD3DZwUob6Rpibgu0iauf2KFGA', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='run--afcbb26d-3a81-4036-8013-e2af2ee916af-0', usage_metadata={'input_tokens': 378, 'output_tokens': 269, 'total_tokens': 647, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}})}

# %%
if result.get("final_plan"):
    if isinstance(result["final_plan"], dict) and "message" in result["final_plan"]:
        display(Markdown(result["final_plan"]["message"]))
    else:
        display(Markdown(result["final_plan"].content))
# Out:
# ## Overview
# The trip is planned from Asansol to Goa on the 2nd of October, 2025. The return date and duration of the stay are not specified. There are no specific budget constraints or interests mentioned for this trip.
#
# ## Transport Options
# 1. **Train, Plane, Taxi, Bus**: This is the quickest way to get from Asansol to Goa. The journey will take approximately 1035 minutes and the cost per person is $301.
#
# 2. **Train, Bus**: This is the cheapest way to get from Asansol to Goa. The journey will take approximately 2780 minutes and the cost per person ranges from ₹1,600 to ₹15,000.
#
# 3. **Train**: There is also an option to travel only by train from Asansol to Goa. The journey will take approximately 2675 minutes. The price for this option is not specified.
#
# 4. **Train**: For the return journey from Goa to Asansol, the train is an option. The journey will take approximately 2816 minutes. The price for this option is not specified.
#
# 5. **Train, Flight**: Another option is to travel by train and flight via Kolkata from Asansol to Goa. The journey will take approximately 600 minutes. The price for this option is not specified.

# %%
# Test the graph for hotel only
input_text= "I want to go to Goa on 2nd October, 2025. I want to stay for 3 nights in a 5-star hotel. provide me the best hotels"
result = graph.invoke({"goal": input_text})
print(result)
# Out:
# Supervisor raw output: hotel_only
# {
#   "origin": null,
#   "city": "Goa",
#   "date": "2025-10-02",
#   "return_date": null,
#   "days": 3,
#   "budget_per_person": null,
#   "interests": null,
#   "transport_constraints": null,
#   "hotel_constraints": {
#     "star_rating": 5
#   }
# }
# In hotel node
# Hotel search query: Hotels in Goa check-in on 2025-10-02 for 3 night(s), budget any, interests: none. Return hotel name, rating, price per night, distance from center, and amenities.
# Raw search result: {'query': 'Hotels in Goa check-in on 2025-10-02 for 3 night(s), budget any, interests: none. Return hotel name, rating, price per night, distance from center, and amenities.', 'follow_up_questions': None, 'answer': None, 'images': [], 'results': [{'url': 'https://www.tripadvisor.com/Hotels-g297604-Goa-Hotels.html', 'title': 'THE 10 BEST Hotels in Goa, India 2025 (from $11)', 'content': 'Seashell Suites and Villas, The Astor - All Suites Hotel Candolim Goa, and Zone Connect By The Park Calangute Goa are all popular resorts', 'score': 0.73846215, 'raw_content': None}, {'url': 'https://www.booking.com/region/in/goa.html', 'title': 'Search the TOP Hotels in Goa, India - Book Today', 'content': 'The averageprice per night for a 3-starhotelinGoathis weekend is $47 or $81for a4-starhotel. Looking for something even fancier? 5-starhotelsinGoa', 'score': 0.5249554, 'raw_content': None}, {'url': 'https://www.expedia.com/Destinations-In-Goa.d6049928.Hotel-Destinations', 'title': 'Top Goa Hotels: 2025 Best Hotels in Goa', 'content': '# Find hotels in Goa for you "This was a fantastic stay at Goa Radisson Blu, we enjoyed the quietness, serenity, private beach access and staff service. ## Find out more about Goa ## Find out more about Goa Whether you\'re seeking a family-friendly getaway, a serene beach escape, or a business-friendly stay, Goa\'s hotels cater to all preferences. ### Where to stay in Goa Goa is the perfect destination for beach lovers and culture enthusiasts alike, offering a variety of activities such as visiting vibrant public markets, enjoying thrilling casino experiences, and exploring the great outdoors. * **The most and least expensive months on average to stay in a hotel:** The cheapest months to stay in Goa are May to June and September, where the prices are slightly lower.', 'score': 0.5246632, 'raw_content': None}, {'url': 'https://www.hotels.com/re679086/hotels-in-goa-india/', 'title': 'Best Hotels in Goa', 'content': '# Goa Hotels ### Novotel Goa Resort & Spa Hotel Novotel Goa Resort & Spa Hotel ### Novotel Goa Candolim Hotel Novotel Goa Candolim Hotel ### Hilton Goa Resort Candolim Hilton Goa Resort Candolim ## Find out more about Goa ## Find out more about Goa Goa offers a diverse range of accommodations, from cozy beachside resorts to luxurious star hotels. 2. **Taj Cidade de Goa HorizonOpens in a new window**: Located in Panaji, this 5.0-star hotel is a romantic getaway, boasting direct beach access and luxurious amenities. 3. **The St. Regis Goa ResortOpens in a new window**: Nestled in Cavelossim, this remarkable 5.0-star resort is tailored for leisure travelers seeking a serene beach vacation.', 'score': 0.5201313, 'raw_content': None}, {'url': 'https://www.booking.com/city/in/goa-in.html', 'title': '10 Best Goa Hotels, India (From $13)', 'content': 'Located within 1.3 miles of Varca Beach and 6.7 miles of Margao Train Station, Hotel O Casa De Elevterio has rooms in Goa. Located in Goa, within 18 miles of Margao Train Station and 28 miles of Basilica of Bom Jesus, Super Townhouse Calangute Formerly Hotel Horizon provides a bar. Many families visiting Goa loved staying at SPOT ON S.k Guest House, Super Townhouse Calangute - Baga Circle Formerly Park Avenue, and Hotel O Kams Coco De Parra. FabHotel Prime PAS Resorts - A Lake View Hotel, Super Townhouse Calangute - Baga Circle Formerly Park Avenue, and Sort By Stays, Grand Peddem, Anjuna are some of the popular hotels in Goa.', 'score': 0.42233846, 'raw_content': None}], 'response_time': 5.15, 'request_id': '21b3fc0d-6242-49e8-bd50-099fbfe48261'}
# LLM hotel options raw output: content='[\n  {\n    "name": "Seashell Suites and Villas",\n    "rating": null,\n    "price_per_night": 0,\n    "distance_from_center_km": null,\n    "amenities": [],\n    "notes": null\n  },\n  {\n    "name": "The Astor - All Suites Hotel Candolim Goa",\n    "rating": null,\n    "price_per_night": 0,\n    "distance_from_center_km": null,\n    "amenities": [],\n    "notes": null\n  },\n  {\n    "name": "Zone Connect By The Park Calangute Goa",\n    "rating": null,\n    "price_per_night": 0,\n    "distance_from_center_km": null,\n    "amenities": [],\n    "notes": null\n  },\n  {\n    "name": "Goa Radisson Blu",\n    "rating": null,\n    "price_per_night": 0,\n    "distance_from_center_km": null,\n    "amenities": ["private beach access"],\n    "notes": null\n  },\n  {\n    "name": "Novotel Goa Resort & Spa Hotel",\n    "rating": null,\n    "price_per_night": 0,\n    "distance_from_center_km": null,\n    "amenities": [],\n    "notes": null\n  },\n  {\n    "name": "Novotel Goa Candolim Hotel",\n    "rating": null,\n    "price_per_night": 0,\n    "distance_from_center_km": null,\n    "amenities": [],\n    "notes": null\n  },\n  {\n    "name": "Hilton Goa Resort Candolim",\n    "rating": null,\n    "price_per_night": 0,\n    "distance_from_center_km": null,\n    "amenities": [],\n    "notes": null\n  },\n  {\n    "name": "Taj Cidade de Goa Horizon",\n    "rating": 5.0,\n    "price_per_night": 0,\n    "distance_from_center_km": null,\n    "amenities": ["direct beach access", "luxurious amenities"],\n    "notes": null\n  },\n  {\n    "name": "The St. Regis Goa Resort",\n    "rating": 5.0,\n    "price_per_night": 0,\n    "distance_from_center_km": null,\n    "amenities": [],\n    "notes": null\n  },\n  {\n    "name": "Hotel O Casa De Elevterio",\n    "rating": null,\n    "price_per_night": 0,\n    "distance_from_center_km": null,\n    "amenities": [],\n    "notes": null\n  },\n  {\n    "name": "Super Townhouse Calangute Formerly Hotel Horizon",\n    "rating": null,\n    "price_per_night": 0,\n    "distance_from_center_km": null,\n    "amenities": [],\n    "notes": null\n  },\n  {\n    "name": "SPOT ON S.k Guest House",\n    "rating": null,\n    "price_per_night": 0,\n    "distance_from_center_km": null,\n    "amenities": [],\n    "notes": null\n  },\n  {\n    "name": "Super Townhouse Calangute - Baga Circle Formerly Park Avenue",\n    "rating": null,\n    "price_per_night": 0,\n    "distance_from_center_km": null,\n    "amenities": [],\n    "notes": null\n  },\n  {\n    "name": "Hotel O Kams Coco De Parra",\n    "rating": null,\n    "price_per_night": 0,\n    "distance_from_center_km": null,\n    "amenities": [],\n    "notes": null\n  },\n  {\n    "name": "FabHotel Prime PAS Resorts - A Lake View Hotel",\n    "rating": null,\n    "price_per_night": 0,\n    "distance_from_center_km": null,\n    "amenities": [],\n    "notes": null\n  },\n  {\n    "name": "Sort By Stays, Grand Peddem, Anjuna",\n    "rating": null,\n    "price_per_night": 0,\n    "distance_from_center_km": null,\n    "amenities": [],\n    "notes": null\n  }\n]' additional_kwargs={'refusal': None} response_metadata={'token_usage': {'completion_tokens': 908, 'prompt_tokens': 1063, 'total_tokens': 1971, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-4-0613', 'system_fingerprint': None, 'id': 'chatcmpl-CHNFvgYcTx2bZSWlRrC7QkaLsfWOf', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None} id='run--a29cc512-cf05-4624-a150-4d3515c9b58a-0' usage_metadata={'input_tokens': 1063, 'output_tokens': 908, 'total_tokens': 1971, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}
# LLM hotel options content: [
#   {
#     "name": "Seashell Suites and Villas",
#     "rating": null,
#     "price_per_night": 0,
#     "distance_from_center_km": null,
#     "amenities": [],
#     "notes": null
#   },
#   {
#     "name": "The Astor - All Suites Hotel Candolim Goa",
#     "rating": null,
#     "price_per_night": 0,
#     "distance_from_center_km": null,
#     "amenities": [],
#     "notes": null
#   },
#   {
#     "name": "Zone Connect By The Park Calangute Goa",
#     "rating": null,
#     "price_per_night": 0,
#     "distance_from_center_km": null,
#     "amenities": [],
#     "notes": null
#   },
#   {
#     "name": "Goa Radisson Blu",
#     "rating": null,
#     "price_per_night": 0,
#     "distance_from_center_km": null,
#     "amenities": ["private beach access"],
#     "notes": null
#   },
#   {
#     "name": "Novotel Goa Resort & Spa Hotel",
#     "rating": null,
#     "price_per_night": 0,
#     "distance_from_center_km": null,
#     "amenities": [],
#     "notes": null
#   },
#   {
#     "name": "Novotel Goa Candolim Hotel",
#     "rating": null,
#     "price_per_night": 0,
#     "distance_from_center_km": null,
#     "amenities": [],
#     "notes": null
#   },
#   {
#     "name": "Hilton Goa Resort Candolim",
#     "rating": null,
#     "price_per_night": 0,
#     "distance_from_center_km": null,
#     "amenities": [],
#     "notes": null
#   },
#   {
#     "name": "Taj Cidade de Goa Horizon",
#     "rating": 5.0,
#     "price_per_night": 0,
#     "distance_from_center_km": null,
#     "amenities": ["direct beach access", "luxurious amenities"],
#     "notes": null
#   },
#   {
#     "name": "The St. Regis Goa Resort",
#     "rating": 5.0,
#     "price_per_night": 0,
#     "distance_from_center_km": null,
#     "amenities": [],
#     "notes": null
#   },
#   {
#     "name": "Hotel O Casa De Elevterio",
#     "rating": null,
#     "price_per_night": 0,
#     "distance_from_center_km": null,
#     "amenities": [],
#     "notes": null
#   },
#   {
#     "name": "Super Townhouse Calangute Formerly Hotel Horizon",
#     "rating": null,
#     "price_per_night": 0,
#     "distance_from_center_km": null,
#     "amenities": [],
#     "notes": null
#   },
#   {
#     "name": "SPOT ON S.k Guest House",
#     "rating": null,
#     "price_per_night": 0,
#     "distance_from_center_km": null,
#     "amenities": [],
#     "notes": null
#   },
#   {
#     "name": "Super Townhouse Calangute - Baga Circle Formerly Park Avenue",
#     "rating": null,
#     "price_per_night": 0,
#     "distance_from_center_km": null,
#     "amenities": [],
#     "notes": null
#   },
#   {
#     "name": "Hotel O Kams Coco De Parra",
#     "rating": null,
#     "price_per_night": 0,
#     "distance_from_center_km": null,
#     "amenities": [],
#     "notes": null
#   },
#   {
#     "name": "FabHotel Prime PAS Resorts - A Lake View Hotel",
#     "rating": null,
#     "price_per_night": 0,
#     "distance_from_center_km": null,
#     "amenities": [],
#     "notes": null
#   },
#   {
#     "name": "Sort By Stays, Grand Peddem, Anjuna",
#     "rating": null,
#     "price_per_night": 0,
#     "distance_from_center_km": null,
#     "amenities": [],
#     "notes": null
#   }
# ]
# Final plan summary raw output: content="## Overview\nThe user is planning a 3-day trip to Goa, starting from October 2, 2025. The user has not specified a budget but is interested in 5-star hotel accommodations.\n\n## Hotel Options\nHere are the 5-star hotel options available for the user's stay:\n\n1. **Seashell Suites and Villas**: This hotel does not have a specified rating or amenities. The price per night is not provided.\n\n2. **The Astor - All Suites Hotel Candolim Goa**: This hotel does not have a specified rating or amenities. The price per night is not provided.\n\n3. **Zone Connect By The Park Calangute Goa**: This hotel does not have a specified rating or amenities. The price per night is not provided.\n\n4. **Goa Radisson Blu**: This hotel does not have a specified rating but offers private beach access. The price per night is not provided.\n\n5. **Novotel Goa Resort & Spa Hotel**: This hotel does not have a specified rating or amenities. The price per night is not provided.\n\n6. **Novotel Goa Candolim Hotel**: This hotel does not have a specified rating or amenities. The price per night is not provided.\n\n7. **Hilton Goa Resort Candolim**: This hotel does not have a specified rating or amenities. The price per night is not provided.\n\n8. **Taj Cidade de Goa Horizon**: This 5-star hotel offers direct beach access and luxurious amenities. The price per night is not provided.\n\n9. **The St. Regis Goa Resort**: This 5-star hotel does not have specified amenities. The price per night is not provided.\n\nThe remaining hotels do not meet the user's 5-star rating requirement. Please note that the prices per night for all hotels are not provided." additional_kwargs={'refusal': None} response_metadata={'token_usage': {'completion_tokens': 369, 'prompt_tokens': 769, 'total_tokens': 1138, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-4-0613', 'system_fingerprint': None, 'id': 'chatcmpl-CHNGMIzlOEQAeYKnCZOOjfdWkQbrR', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None} id='run--bfc7ea0a-da6b-48f6-9d25-1a02bc1628da-0' usage_metadata={'input_tokens': 769, 'output_tokens': 369, 'total_tokens': 1138, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}
# {'goal': 'I want to go to Goa on 2nd October, 2025. I want to stay for 3 nights in a 5-star hotel. provide me the best hotels', 'intent': 'hotel_only', 'constraints': Constraints(origin=None, city='Goa', date='2025-10-02', return_date=None, days=3, budget_per_person=None, interests=None, transport_constraints=None, hotel_constraints={'star_rating': 5}), 'transport_options': [], 'hotel_options': [HotelOption(name='Seashell Suites and Villas', rating=None, price_per_night=0.0, distance_from_center_km=None, amenities=[], notes=None), HotelOption(name='The Astor - All Suites Hotel Candolim Goa', rating=None, price_per_night=0.0, distance_from_center_km=None, amenities=[], notes=None), HotelOption(name='Zone Connect By The Park Calangute Goa', rating=None, price_per_night=0.0, distance_from_center_km=None, amenities=[], notes=None), HotelOption(name='Goa Radisson Blu', rating=None, price_per_night=0.0, distance_from_center_km=None, amenities=['private beach access'], notes=None), HotelOption(name='Novotel Goa Resort & Spa Hotel', rating=None, price_per_night=0.0, distance_from_center_km=None, amenities=[], notes=None), HotelOption(name='Novotel Goa Candolim Hotel', rating=None, price_per_night=0.0, distance_from_center_km=None, amenities=[], notes=None), HotelOption(name='Hilton Goa Resort Candolim', rating=None, price_per_night=0.0, distance_from_center_km=None, amenities=[], notes=None), HotelOption(name='Taj Cidade de Goa Horizon', rating=5.0, price_per_night=0.0, distance_from_center_km=None, amenities=['direct beach access', 'luxurious amenities'], notes=None), HotelOption(name='The St. Regis Goa Resort', rating=5.0, price_per_night=0.0, distance_from_center_km=None, amenities=[], notes=None), HotelOption(name='Hotel O Casa De Elevterio', rating=None, price_per_night=0.0, distance_from_center_km=None, amenities=[], notes=None), HotelOption(name='Super Townhouse Calangute Formerly Hotel Horizon', rating=None, price_per_night=0.0, distance_from_center_km=None, amenities=[], notes=None), HotelOption(name='SPOT ON S.k Guest House', rating=None, price_per_night=0.0, distance_from_center_km=None, amenities=[], notes=None), HotelOption(name='Super Townhouse Calangute - Baga Circle Formerly Park Avenue', rating=None, price_per_night=0.0, distance_from_center_km=None, amenities=[], notes=None), HotelOption(name='Hotel O Kams Coco De Parra', rating=None, price_per_night=0.0, distance_from_center_km=None, amenities=[], notes=None), HotelOption(name='FabHotel Prime PAS Resorts - A Lake View Hotel', rating=None, price_per_night=0.0, distance_from_center_km=None, amenities=[], notes=None), HotelOption(name='Sort By Stays, Grand Peddem, Anjuna', rating=None, price_per_night=0.0, distance_from_center_km=None, amenities=[], notes=None)], 'itinerary': [], 'final_plan': AIMessage(content="## Overview\nThe user is planning a 3-day trip to Goa, starting from October 2, 2025. The user has not specified a budget but is interested in 5-star hotel accommodations.\n\n## Hotel Options\nHere are the 5-star hotel options available for the user's stay:\n\n1. **Seashell Suites and Villas**: This hotel does not have a specified rating or amenities. The price per night is not provided.\n\n2. **The Astor - All Suites Hotel Candolim Goa**: This hotel does not have a specified rating or amenities. The price per night is not provided.\n\n3. **Zone Connect By The Park Calangute Goa**: This hotel does not have a specified rating or amenities. The price per night is not provided.\n\n4. **Goa Radisson Blu**: This hotel does not have a specified rating but offers private beach access. The price per night is not provided.\n\n5. **Novotel Goa Resort & Spa Hotel**: This hotel does not have a specified rating or amenities. The price per night is not provided.\n\n6. **Novotel Goa Candolim Hotel**: This hotel does not have a specified rating or amenities. The price per night is not provided.\n\n7. **Hilton Goa Resort Candolim**: This hotel does not have a specified rating o ...

# %%
if result.get("final_plan"):
    if isinstance(result["final_plan"], dict) and "message" in result["final_plan"]:
        display(Markdown(result["final_plan"]["message"]))
    else:
        display(Markdown(result["final_plan"].content))
# Out:
# ## Overview
# The user is planning a 3-day trip to Goa, starting from October 2, 2025. The user has not specified a budget but is interested in 5-star hotel accommodations.
#
# ## Hotel Options
# Here are the 5-star hotel options available for the user's stay:
#
# 1. **Seashell Suites and Villas**: This hotel does not have a specified rating or amenities. The price per night is not provided.
#
# 2. **The Astor - All Suites Hotel Candolim Goa**: This hotel does not have a specified rating or amenities. The price per night is not provided.
#
# 3. **Zone Connect By The Park Calangute Goa**: This hotel does not have a specified rating or amenities. The price per night is not provided.
#
# 4. **Goa Radisson Blu**: This hotel does not have a specified rating but offers private beach access. The price per night is not provided.
#
# 5. **Novotel Goa Resort & Spa Hotel**: This hotel does not have a specified rating or amenities. The price per night is not provided.
#
# 6. **Novotel Goa Candolim Hotel**: This hotel does not have a specified rating or amenities. The price per night is not provided.
#
# 7. **Hilton Goa Resort Candolim**: This hotel does not have a specified rating or amenities. The price per night is not provided.
#
# 8. **Taj Cidade de Goa Horizon**: This 5-star hotel offers direct beach access and luxurious amenities. The price per night is not provided.
#
# 9. **The St. Regis Goa Resort**: This 5-star hotel does not have specified amenities. The price per night is not provided.
#
# The remaining hotels do not meet the user's 5-star rating requirement. Please note that the prices per night for all hotels are not provided.

# %%
# Test the graph for unrelated
input_text= "What is the capital of Maharashtra?"
result = graph.invoke({"goal": input_text})
print(result)
# Out:
# Supervisor raw output: unrelated
# {'goal': 'What is the capital of Maharashtra?', 'intent': 'unrelated', 'final_plan': {'message': 'The request was unrelated to travel planning.'}}
